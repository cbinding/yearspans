# %%
# pre-install required libraries
import warnings
#%pip install -upgrade pip
#%pip install spacy
# suppress user warnings during execution
warnings.filterwarnings(action='ignore', category=UserWarning)

# %% [markdown]
# # Using the Year Span Matcher
# ## Introduction
# The Year Span Matcher determines start/end years from textual expressions of year periods.

# %%
from yearspanmatcher.yearspanmatcher import getMatcherForLanguage
from yearspanmatcher.yearspan import YearSpan
from IPython.display import display, HTML
import pandas as pd  # for DataFrame output

# test items (English)
items1 = [
    "January 1066 AD",
    "Early 11th Century AD",
    "Early Eleventh Century BC",
    "early 11th to late 12th century AD",
    "1600-25+17",
    "1600±17",
    "1250 - 57 AD",
    "Edwardian",
    "1850's"
]

# test items (Norwegian)
items97507 = [
    "romertid",
    "folkevandringstid",
    "førromersk jernalder",
    "yngre bronsealder",
    "nyere tid",
    "folkevandringstid",
    "romertid",
    "folkevandringstid"
]

# test items (Norwegian)
items71115 = [
    "seinmesolitikum",
    "tidligneolitikum",
    "tidligneolitikum",
    "ca. 4000–3700 f.Kr.",
    "eldre bronsealder",
    "ca. 1400–1050 f.Kr.",
    "eldre jernalder",
    "ca. 250–500 e.Kr.",
    "eldre bronsealder"
]

items71189 = [
    "førromersk jernalder",
    "førromersk jernalder",
    "førromersk jernalder",
    "folkevandringstid"
]

#test items (Czech)
tests_cs = [
    "lednu 1066 n. l.",
    "lednu 1066 př. n. l.",
    "lednu 1066 BP",
    "jaře roku 1066 n. l.",
    "jaře roku 1066 př. n. l.",
    "jaře roku 1066 BP",
    "počátek 11. století našeho letopočtu",
    "počátek 11. století př. n. l.",
    "počátek jedenáctého století našeho letopočtu",
    "Počátek jedenáctého století př. n. l.",
    "počátek 11. až konec 12. století n. l.",
    "počátek 12. až konec 11. století př. n. l.",
    "počátek jedenáctého až konec dvanáctého století našeho letopočtu",
    "počátek dvanáctého až konec jedenáctého století př. n. l.",
    "konec 1. tisíciletí našeho letopočtu",
    "konec 1. tisíciletí př. n. l.",
    "konec 1. až začátek 2. tisíciletí našeho letopočtu",
    "počátek roku 1950 n. l.",
    "počátek roku 1950 př. n. l.",
    "počátek roku 1950 BP",
    "1950 n. l.",
    "1950 př. n. l.",
    "1950 BP",
    "1600-25+17",
    "1600±17",
    "1255 - 7 n. l.",
    "1250 - 57 n. l.",
    "1200 - 1500 n. l.",
    "1500 - 1200 př. n. l.",
    "1200 - 1500 BP",
    "50. léta 20. století",
    "50. až 60. léta 20. století",
    "gravettien",
    "aurignacien",
    "pozdní středověk",
    "plaňanský typ"
]

matcher = getMatcherForLanguage("cs")

# get year span for each test item
results = []
for item in tests_cs:
    span = matcher.match(item)
    if (span is not None):
        result = {"value": item}    
        result["minYear"] = YearSpan.yearToISO8601(span.minYear)
        result["maxYear"] = YearSpan.yearToISO8601(span.maxYear)
        result["isoSpan"] = span.toISO8601()
        results.append(result)

# convert results to pandas dataframe for display  
df = pd.DataFrame(results)
display(df)
# Out:
#                                                 value minYear maxYear  \
# 0                                    lednu 1066 n. l.    1066    1066
# 1                                lednu 1066 př. n. l.   -1065   -1065
# 2                                       lednu 1066 BP    0934    0934
# 3                                jaře roku 1066 n. l.    1066    1066
# 4                            jaře roku 1066 př. n. l.   -1065   -1065
# 5                                   jaře roku 1066 BP    0934    0934
# 6                počátek 11. století našeho letopočtu    1001    1040
# 7                       počátek 11. století př. n. l.   -1099   -1059
# 8        počátek jedenáctého století našeho letopočtu    1001    1040
# 9               Počátek jedenáctého století př. n. l.   -1099   -1059
# 10             počátek 11. až konec 12. století n. l.    1001    1200
# 11         počátek 12. až konec 11. století př. n. l.   -1199   -1000
# 12  počátek jedenáctého až konec dvanáctého stolet...    1001    1200
# 13  počátek dvanáctého až konec jedenáctého stolet...   -1199   -1000
# 14               konec 1. tisíciletí našeho letopočtu    0600    1000
# 15                      konec 1. tisíciletí př. n. l.   -0399    0000
# 16  konec 1. až začátek 2. tisíciletí našeho letop...    0600    1400
# 17                            počátek roku 1950 n. l.    1950    1950
# 18                        počátek roku 1950 př. n. l.   -1949   -1949
# 19                               počátek roku 1950 BP    0050    0050
# 20                                         1950 n. l.    1950    1950
# 21                                     1950 př. n. l.   -1949   -1949
# 22                                            1950 BP    0050    0050
# 23                                         1600-25+17    1575    1617
# 24                                            1600±17    1583    1617
# 25                                     1255 - 7 n. l.    1255    1257
# 26                                    1250 - 57 n. l.    1250    1257
# 27                                  1200 - 1500 n. l.    1200    1500
# 28                              1500 - 1200 př. n. l.   -1499   -1199
# 29                                     1200 - 1500 BP    0500    0800
# 30                               50. léta 20. století    1950    1959
# 31                        50. až 60. léta 20. století    1950    1969
# 32                                         gravettien  -29999  -18000
# 33                                        aurignacien  -37999  -28000
# 34                                   pozdní středověk    1301    1500
# 35                                      plaňanský typ   -0029   -0005
#
#           isoSpan
# 0       1066/1066
# 1     -1065/-1065
# 2       0934/0934
# 3       1066/1066
# 4     -1065/-1065
# 5       0934/0934
# 6       1001/1040
# 7     -1099/-1059
# 8       1001/1040
# 9     -1099/-1059
# 10      1001/1200
# 11    -1199/-1000
# 12      1001/1200
# 13    -1199/-1000
# 14      0600/1000
# 15     -0399/0000
# 16      0600/1400
# 17      1950/1950
# 18    -1949/-1949
# 19      0050/0050
# 20      1950/1950
# 21    -1949/-1949
# 22      0050/0050
# 23      1575/1617
# 24      1583/1617
# 25      1255/1257
# 26      1250/1257
# 27      1200/1500
# 28    -1499/-1199
# 29      0500/0800
# 30      1950/1959
# 31      1950/1969
# 32  -29999/-18000
# 33  -37999/-28000
# 34      1301/1500
# 35    -0029/-0005
